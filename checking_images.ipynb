# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = plt.imread("TrainVal/E10_10-1.ome_8bit.tif")
img_copy = img

# %%
plt.imshow(img)
plt.show()

# %%
ret, thresh =  cv2.threshold(img_copy,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
plt.imshow(thresh2)
plt.show()

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

# %%
len(contours)
# Out:
# 1481

# %%
probable_cell_cnt_2 = list()
all_ars_cnt_2 = list()
for cnt in contours:
    ar_cnt = cv2.contourArea(cnt)
    if ar_cnt > 0:
        all_ars_cnt_2.append(ar_cnt)
        probable_cell_cnt_2.append(cnt)

# %%
cells2 = cv2.drawContours(img, probable_cell_cnt_2, -1, (255, 0, 0), 3)
# cv2.imwrite('probablecells2.jpg', img)

# %%
plt.imshow(cells2)
plt.show()

# %% [markdown]
# ### Converting tiff to jpg

# %%
import os
os.getcwd()
# Out:
# '/home/iki/Desktop/practice/cellvoyant/ML Engineer - candidate assessment'

# %%
# !python3 change_img_format.py
# Out:
# /home/iki/Desktop/practice/cellvoyant/ML Engineer - candidate assessment/TrainVal/E11_11-105.ome_8bit.tif
# Generating jpeg for E11_11-105.ome_8bit.tif
# /home/iki/Desktop/practice/cellvoyant/ML Engineer - candidate assessment/TrainVal/E10_10-97.ome_8bit.tif
# Generating jpeg for E10_10-97.ome_8bit.tif
# /home/iki/Desktop/practice/cellvoyant/ML Engineer - candidate assessment/TrainVal/E11_11-67.ome_8bit.tif
# Generating jpeg for E11_11-67.ome_8bit.tif
# /home/iki/Desktop/practice/cellvoyant/ML Engineer - candidate assessment/TrainVal/E11_11-37.ome_8bit.tif
# Generating jpeg for E11_11-37.ome_8bit.tif
# /home/iki/Desktop/practice/cellvoyant/ML Engineer - candidate assessment/TrainVal/E10_10-71.ome_8bit.tif
# Generating jpeg for E10_10-71.ome_8bit.tif
# /home/iki/Desktop/practice/cellvoyant/ML Engineer - candidate assessment/TrainVal/E10_10-27.ome_8bit.tif
# Generating jpeg for E10_10-27.ome_8bit.tif
# ...
